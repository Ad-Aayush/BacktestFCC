# %%
import pandas as pd
import openpyxl
from collections import defaultdict
import os

# %%
# !pwd
# Out:
# /home/aayush_ad/BacktestFCC

# %%
stock_data_dict = defaultdict(list)

# %%
def load_excel_sheet(file_path):
    try:
        # Load the Excel file, skipping initial empty rows and setting the header
        data = pd.read_excel(file_path, header=3)
        return data
    except Exception as e:
        print(f"Error loading Excel sheet: {str(e)}")
        return None

# %%
from datetime import datetime

start_date = datetime(2012, 7, 2)

def organize_stock_data(df):
    current_stock = None
    for _, row in df.iterrows():
        if pd.notna(row['CD_Bloomberg Code']):
            current_stock = row['CD_Bloomberg Code']
            if current_stock not in stock_data_dict:
                stock_data_dict[current_stock] = []
        
        if current_stock is not None and pd.notna(row['NDP_Date']) and pd.notna(row['NDP_Close']):
            date = row['NDP_Date']
            close = row['NDP_Close']

            # Convert timestamp to date string
            date_str = date.strftime('%Y-%m-%d')

            # Calculate the number of days since the start date
            days_since_start = (date - start_date).days

            stock_data = {'Date': date_str, 'Days Since Start': days_since_start, 'Close': close}
            stock_data_dict[current_stock].append(stock_data)

# %%
def clean_and_concatenate_data():
    for stock, data in stock_data_dict.items():
        stock_data_dict[stock] = pd.concat(data, ignore_index=True).drop_duplicates().reset_index(drop=True)

# %%
file_names = ['Jan13.xlsx', 'Jul14.xlsx', 'Jan14.xlsx', 'Jul15.xlsx', 'Jan15.xlsx', 'Jul16.xlsx', 'Jul17.xlsx', 'Jan17.xlsx', 'Jul18.xlsx', 'Jan18.xlsx', 'Jul19.xlsx', 'Jan19.xlsx', 'Jul20.xlsx', 'Jan20.xlsx', 'Jul21.xlsx', 'Jan22.xlsx', 'Jul23.xlsx', 'Jan23.xlsx'] 

file_directory = 'BacktestingData'

# %%
for file_name in file_names:
    file_path = os.path.join(file_directory, file_name)
    data = load_excel_sheet(file_path)
    if data is not None:
        organize_stock_data(data)
# Out:
# Error loading Excel sheet: [Errno 2] No such file or directory: 'BacktestingData/Jan19.xlsx'

# %%
os.makedirs('Data', exist_ok=True)  # Ensure the 'Data' directory exists
os.chdir('Data')

# %%
for stock, data in stock_data_dict.items():
    formatted_data = pd.DataFrame(data)
    if not formatted_data.empty:
        excel_file_name = f"{stock}.xlsx"
        
        formatted_data.sort_values(by='Days Since Start', inplace=True)
        
        formatted_data.to_excel(excel_file_name, index=False)
        print(f"Data for {stock} saved to {excel_file_name}")
    else:
        print(f"No data available for {stock}")
# Out:
# Data for 360ONE IN saved to 360ONE IN.xlsx
# Data for 3M IN saved to 3M IN.xlsx
# Data for 63MOONS IN saved to 63MOONS IN.xlsx
# Data for ARTD IN saved to ARTD IN.xlsx
# Data for ARTO IN saved to ARTO IN.xlsx
# Data for AAVAS IN saved to AAVAS IN.xlsx
# Data for ABAN IN saved to ABAN IN.xlsx
# Data for BOOT IN saved to BOOT IN.xlsx
# Data for ABGS IN saved to ABGS IN.xlsx
# Data for ACC IN saved to ACC IN.xlsx
# Data for ADANIT IN saved to ADANIT IN.xlsx
# Data for ADE IN saved to ADE IN.xlsx
# Data for ADANIGR IN saved to ADANIGR IN.xlsx
# Data for ADSEZ IN saved to ADSEZ IN.xlsx
# Data for ADANI IN saved to ADANI IN.xlsx
# Data for ATGL IN saved to ATGL IN.xlsx
# Data for AWLTD IN saved to AWLTD IN.xlsx
# Data for ABCAP IN saved to ABCAP IN.xlsx
# Data for ABFRL IN saved to ABFRL IN.xlsx
# Data for ABML IN saved to ABML IN.xlsx
# Data for ABSLAMC IN saved to ABSLAMC IN.xlsx
# Data for ADVENZY IN saved to ADVENZY IN.xlsx
# Data for RMDA IN saved to RMDA IN.xlsx
# Data for AGIS IN saved to AGIS IN.xlsx
# Data for AETHER IN saved to AETHER IN.xlsx
# Data for AFFLE IN saved to AFFLE IN.xlsx
# Data for ATFL IN saved to ATFL IN.xlsx
# Data for AHLU IN saved to AHLU IN.xlsx
# Data for AIAE IN saved to AIAE IN.xlsx
# Data for AJP IN saved to AJP IN.xlsx
# Data for AKZO IN saved to AKZO IN.xlsx
# Data for ALBC IN saved to ALBC IN.xlsx
# Data for ALPM IN saved to ALPM IN.xlsx
# Data for ALKEM IN saved to ALKEM IN.xlsx
# Data for AACL IN saved to AACL IN.xlsx
# Data for ALBK IN saved to ALBK IN.xlsx
# Data for AGLL IN saved to AGLL IN.xlsx
# Data for ALOK IN saved to ALOK IN.xlsx
# No data available for AMHL IN
# Data for AMBER IN saved to AMBER IN.xlsx
# Data for ACEM IN saved to ACEM IN.xlsx
# Data for AMTK IN saved to AMTK IN.xlsx
# Data for ARCP IN saved to ARCP IN.xlsx
# Data for ANGELONE IN saved to ANGELONE IN.xlsx
# Data for ANURAS IN saved to ANURAS IN.xlsx
# Data for APR IN saved to APR IN.xlsx
# Data for APAT IN saved to APAT IN.xlsx
# Data for APHS IN saved to APHS IN.xlsx
# Data for APTY IN saved to APTY IN.xlsx
# Data for APTR IN saved to APTR IN.xlsx
# Data for APTUS IN saved to APTUS IN.xlsx
# Data for ACI IN saved to ACI IN.xlsx
# Data for ARVINDFA IN saved to ARVINDFA IN.xlsx
# Data for AISG IN saved to AISG IN.xlsx
# Data for ASFI IN saved to ASFI IN.xlsx
# Data for AL IN saved to AL IN.xlsx
# Data for ASBL IN saved to ASBL IN.xlsx
# Data for APNT IN saved to APNT IN.xlsx
# Data for ASTERDM IN saved to ASTERDM IN.xlsx
# Data for ASTRA IN saved to ASTRA IN.xlsx
# Data for AUBANK IN saved to AUBANK IN.xlsx
# Data for ARBP IN saved to ARBP IN.xlsx
# Data for ATXL IN saved to ATXL IN.xlsx
# Data for AVNT IN saved to AVNT IN.xlsx
# Data for DMART IN saved to DMART IN.xlsx
# Data for AXSB IN saved to AXSB IN.xlsx
# Data for BJAUT IN saved to BJAUT IN.xlsx
# Data for BAJAJCON IN saved to BAJAJCON IN.xlsx
# Data for BJFIN IN saved to BJFIN IN.xlsx
# Data for BAJAJHEA IN saved to BAJAJHEA IN.xlsx
# Data for BJHI IN saved to BJHI IN.xlsx
# Data for BLA IN saved to BLA IN.xlsx
# Data for BIL IN saved to BIL IN.xlsx
# Data for BANDHAN IN saved to BANDHAN IN.xlsx
# Data for BOB IN saved to BOB IN.xlsx
# Data for BOI IN saved to BOI IN.xlsx
# Data for BOMH IN saved to BOMH IN.xlsx
# Data for BYRCS IN saved to BYRCS IN.xlsx
# Data for BRGR IN saved to BRGR IN.xlsx
# Data for BFUT IN saved to BFUT IN.xlsx
# No data available for BFTL IN
# Data for BDL IN saved to BDL IN.xlsx
# Data for BHAFIN IN saved to BHAFIN IN.xlsx
# Data for BHFC IN saved to BHFC IN.xlsx
# Data for BPCL IN saved to BPCL IN.xlsx
# Data for BRSN IN saved to BRSN IN.xlsx
# Data for BHARTI IN saved to BHARTI IN.xlsx
# No data available for BHUDEVI IN
# Data for BIKAJI IN saved to BIKAJI IN.xlsx
# Data for BIOS IN saved to BIOS IN.xlsx
# Data for BCORP IN saved to BCORP IN.xlsx
# Data for BSOFT IN saved to BSOFT IN.xlsx
# Data for BLIS IN saved to BLIS IN.xlsx
# Data for BLSIN IN saved to BLSIN IN.xlsx
# Data for BDE IN saved to BDE IN.xlsx
# Data for BBTC IN saved to BBTC IN.xlsx
# No data available for BCMA IN
# Data for BRFL IN saved to BRFL IN.xlsx
# Data for BORORENE IN saved to BORORENE IN.xlsx
# Data for BOS IN saved to BOS IN.xlsx
# Data for BRGD IN saved to BRGD IN.xlsx
# Data for BCG IN saved to BCG IN.xlsx
# Data for BRIT IN saved to BRIT IN.xlsx
# Data for BSE IN saved to BSE IN.xlsx
# Data for CCON IN saved to CCON IN.xlsx
# Data for CADSYS IN saved to CADSYS IN.xlsx
# Data for CFIN IN saved to CFIN IN.xlsx
# Data for CAMPUS IN saved to CAMPUS IN.xlsx
# Data for CANF IN saved to CANF IN.xlsx
# Data for CBK IN saved to CBK IN.xlsx
# Data for CAFL IN saved to CAFL IN.xlsx
# Data for CLPL IN saved to CLPL IN.xlsx
# Data for CGCL IN saved to CGCL IN.xlsx
# Data for CU IN saved to CU IN.xlsx
# Data for CARE IN saved to CARE IN.xlsx
# Data for CAST IN saved to CAST IN.xlsx
# Data for CSTRL IN saved to CSTRL IN.xlsx
# No data available for CRCL IN
# Data for CEAT IN saved to CEAT IN.xlsx
# Data for CBOI IN saved to CBOI IN.xlsx
# Data for CDSL IN saved to CDSL IN.xlsx
# Data for CENK IN saved to CENK IN.xlsx
# Data for CPBI IN saved to CPBI IN.xlsx
# Data for CHALET IN saved to CHALET IN.xlsx
# Data for CHEMPLAS IN saved to CHEMPLAS IN.xlsx
# Data for CHOLAHLD IN saved to CHOLAHLD IN.xlsx
# Data for CIFC IN saved to CIFC IN.xlsx
# Data for CIEINDIA IN saved to CIEINDIA IN.xlsx
# Data for CUBK IN saved to CUBK IN.xlsx
# Data for CLEDU IN saved to CLEDU IN.xlsx
# Data for CLEAN IN saved to CLEAN IN.xlsx
# Data for CLTO IN saved to CLTO IN.xlsx
# Data for COAL IN saved to COAL IN.xlsx
# Data for COCHIN IN saved to COCHIN IN.xlsx
# Data for CCD IN saved to CCD IN.xlsx
# Data for COFORGE IN saved to COFORGE IN.xlsx
# Data for CLGT IN saved to CLGT IN.xlsx
# Data for CAMS IN saved to CAMS IN.xlsx
# Data for CCRI IN saved to CCRI IN.xlsx
# Data for CETL IN saved to CETL IN.xlsx
# Data for CRIN IN saved to CRIN IN.xlsx
# No data available for CMBL IN
# Data for COXK IN saved to COXK IN.xlsx
# Data for CRAFTSMA IN saved to CRAFTSMA IN.xlsx
# Data for CREDAG IN saved to CREDAG IN.xlsx
# Data for CROMPTON IN saved to CROMPTON IN.xlsx
# Data for CSBBANK IN saved to CSBBANK IN.xlsx
# Data for KKC IN saved to KKC IN.xlsx
# Data for CYL IN saved to CYL IN.xlsx
# Data for DBCL IN saved to DBCL IN.xlsx
# Data for DALBHARA IN saved to DALBHARA IN.xlsx
# Data for DATAPATT IN saved to DATAPATT IN.xlsx
# Data for DCI IN saved to DCI IN.xlsx
# Data for DCBB IN saved to DCBB IN.xlsx
# Data for DCMNVL IN saved to DCMNVL IN.xlsx
# Data for DCMS IN saved to DCMS IN.xlsx
# Data for DFPC IN saved to DFPC IN.xlsx
# Data for DN IN saved to DN IN.xlsx
# Data for DELHIVER IN saved to DELHIVER IN.xlsx
# Data for DELTA IN saved to DELTA IN.xlsx
# Data for DEN IN saved to DEN IN.xlsx
# Data for DEVYANI IN saved to DEVYANI IN.xlsx
# Data for DHANI IN saved to DHANI IN.xlsx
# Data for DHLBK IN saved to DHLBK IN.xlsx
# Data for DAGRI IN saved to DAGRI IN.xlsx
# Data for DBL IN saved to DBL IN.xlsx
# Data for DITV IN saved to DITV IN.xlsx
# Data for DCAL IN saved to DCAL IN.xlsx
# Data for DIVI IN saved to DIVI IN.xlsx
# Data for DIXON IN saved to DIXON IN.xlsx
# Data for DLFU IN saved to DLFU IN.xlsx
# Data for DDLL IN saved to DDLL IN.xlsx
# Data for DCIL IN saved to DCIL IN.xlsx
# No data available for DKOF IN
# Data for DYTC IN saved to DYTC IN.xlsx
# Data for EASEMYTR IN saved to EASEMYTR IN.xlsx
# Data for ECLX IN saved to ECLX IN.xlsx
# Data for EDEL IN saved to EDEL IN.xlsx
# Data for EDSL IN saved to EDSL IN.xlsx
# Data for EIM IN saved to EIM IN.xlsx
# Data for EIH IN saved to EIH IN.xlsx
# Data for ELDP IN saved to ELDP IN.xlsx
# Data for ELEQ IN saved to ELEQ IN.xlsx
# Data for HMN IN saved to HMN IN.xlsx
# Data for ENDU IN saved to ENDU IN.xlsx
# Data for ENGR IN saved to ENGR IN.xlsx
# Data for ENIL IN saved to ENIL IN.xlsx
# Data for EQUIPPP IN saved to EQUIPPP IN.xlsx
# Data for EQUITASB IN saved to EQUITASB IN.xlsx
# Data for ERIE IN saved to ERIE IN.xlsx
# Data for ERIS IN saved to ERIS IN.xlsx
# Data for EROS IN saved to EROS IN.xlsx
# Data for ESCORTS IN saved to ESCORTS IN.xlsx
# Data for EDA IN saved to EDA IN.xlsx
# Data for ESL IN saved to ESL IN.xlsx
# Data for EVRIN IN saved to EVRIN IN.xlsx
# No data available for EXLI IN
# No data available for FCTS IN
# Data for FDCLT IN saved to FDCLT IN.xlsx
# Data for FMGI IN saved to FMGI IN.xlsx
# No data available for FCCI IN
# Data for FINEORG IN saved to FINEORG IN.xlsx
# Data for FNXP IN saved to FNXP IN.xlsx
# Data for FSOL IN saved to FSOL IN.xlsx
# Data for FIVESTAR IN saved to FIVESTAR IN.xlsx
# No data available for FLXF IN
# Data for FORH IN saved to FORH IN.xlsx
# Data for NYKAA IN saved to NYKAA IN.xlsx
# No data available for FPL IN
# Data for FCON IN saved to FCON IN.xlsx
# Data for FLFL IN saved to FLFL IN.xlsx
# Data for FRETAIL IN saved to FRETAIL IN.xlsx
# No data available for FSL IN
# Data for GABR IN saved to GABR IN.xlsx
# Data for GAIL IN saved to GAIL IN.xlsx
# Data for GALSURF IN saved to GALSURF IN.xlsx
# Data for GMON IN saved to GMON IN.xlsx
# Data for GRSE IN saved to GRSE IN.xlsx
# Data for GTFL IN saved to GTFL IN.xlsx
# Data for GTIC IN saved to GTIC IN.xlsx
# Data for GAYP IN saved to GAYP IN.xlsx
# Data for GBGLOBAL IN saved to GBGLOBAL IN.xlsx
# Data for GEPIL IN saved to GEPIL IN.xlsx
# Data for GETD IN saved to GETD IN.xlsx
# Data for GICRE IN saved to GICRE IN.xlsx
# No data available for GENP IN
# No data available for GSI IN
# Data for GILL IN saved to GILL IN.xlsx
# Data for GITG IN saved to GITG IN.xlsx
# Data for GLAND IN saved to GLAND IN.xlsx
# Data for GLXO IN saved to GLXO IN.xlsx
# Data for GLS IN saved to GLS IN.xlsx
# Data for GNP IN saved to GNP IN.xlsx
# Data for MEDANTA IN saved to MEDANTA IN.xlsx
# Data for GWOS IN saved to GWOS IN.xlsx
# Data for GMM IN saved to GMM IN.xlsx
# Data for GMRI IN saved to GMRI IN.xlsx
# Data for GOCOLORS IN saved to GOCOLORS IN.xlsx
# Data for GOAGRO IN saved to GOAGRO IN.xlsx
# Data for GCPL IN saved to GCPL IN.xlsx
# Data for GPL IN saved to GPL IN.xlsx
# Data for GOFF IN saved to GOFF IN.xlsx
# Data for GRAN IN saved to GRAN IN.xlsx
# Data for GRIL IN saved to GRIL IN.xlsx
# Data for GRASIM IN saved to GRASIM IN.xlsx
# No data available for GRSM IN
# Data for GRV IN saved to GRV IN.xlsx
# Data for GREENP IN saved to GREENP IN.xlsx
# Data for MTLM IN saved to MTLM IN.xlsx
# Data for GWN IN saved to GWN IN.xlsx
# Data for GRP IN saved to GRP IN.xlsx
# Data for GTLI IN saved to GTLI IN.xlsx
# Data for CF IN saved to CF IN.xlsx
# Data for GAEX IN saved to GAEX IN.xlsx
# Data for FLUOROCH IN saved to FLUOROCH IN.xlsx
# No data available for GJF IN
# Data for GUJGA IN saved to GUJGA IN.xlsx
# No data available for GUJSPIN IN
# Data for GMDC IN saved to GMDC IN.xlsx
# Data for GNFC IN saved to GNFC IN.xlsx
# Data for GNC IN saved to GNC IN.xlsx
# Data for GPPV IN saved to GPPV IN.xlsx
# Data for GSFC IN saved to GSFC IN.xlsx
# Data for GUJS IN saved to GUJS IN.xlsx
# Data for GOLI IN saved to GOLI IN.xlsx
# Data for GVKP IN saved to GVKP IN.xlsx
# Data for HAPPSTMN IN saved to HAPPSTMN IN.xlsx
# Data for HATH IN saved to HATH IN.xlsx
# Data for HTSMF IN saved to HTSMF IN.xlsx
# Data for HAVL IN saved to HAVL IN.xlsx
# Data for HCLI IN saved to HCLI IN.xlsx
# Data for HCLT IN saved to HCLT IN.xlsx
# Data for HDFCAMC IN saved to HDFCAMC IN.xlsx
# Data for HDFCB IN saved to HDFCB IN.xlsx
# Data for HDFCLIFE IN saved to HDFCLIFE IN.xlsx
# Data for HEG IN saved to HEG IN.xlsx
# Data for HEIM IN saved to HEIM IN.xlsx
# Data for HEMIPROP IN saved to HEMIPROP IN.xlsx
# Data for HTFL IN saved to HTFL IN.xlsx
# Data for HMCL IN saved to HMCL IN.xlsx
# Data for HMFC IN saved to HMFC IN.xlsx
# Data for HKCI IN saved to HKCI IN.xlsx
# No data available for HMF IN
# Data for HSCH IN saved to HSCH IN.xlsx
# Data for HSS IN saved to HSS IN.xlsx
# Data for HNDL IN saved to HNDL IN.xlsx
# Data for HGSL IN saved to HGSL IN.xlsx
# Data for HNAL IN saved to HNAL IN.xlsx
# Data for HDCM IN saved to HDCM IN.xlsx
# Data for HCP IN saved to HCP IN.xlsx
# No data available for HHC IN
# Data for HM IN saved to HM IN.xlsx
# Data for HUVR IN saved to HUVR IN.xlsx
# Data for HZ IN saved to HZ IN.xlsx
# Data for POWERIND IN saved to POWERIND IN.xlsx
# Data for HLEGLAS IN saved to HLEGLAS IN.xlsx
# Data for HLV IN saved to HLV IN.xlsx
# Data for HMT IN saved to HMT IN.xlsx
# Data for HOMEFIRS IN saved to HOMEFIRS IN.xlsx
# Data for HWA IN saved to HWA IN.xlsx
# Data for HUDCO IN saved to HUDCO IN.xlsx
# Data for HDIL IN saved to HDIL IN.xlsx
# No data available for HSPL IN
# Data for HTML IN saved to HTML IN.xlsx
# Data for HUB IN saved to HUB IN.xlsx
# Data for HUIN IN saved to HUIN IN.xlsx
# No data available for NYC IN
# Data for ICICIBC IN saved to ICICIBC IN.xlsx
# Data for ICICIGI IN saved to ICICIGI IN.xlsx
# Data for IPRU IN saved to IPRU IN.xlsx
# Data for ISEC IN saved to ISEC IN.xlsx
# Data for ICRA IN saved to ICRA IN.xlsx
# Data for IDFCFB IN saved to IDFCFB IN.xlsx
# Data for IDFC IN saved to IDFC IN.xlsx
# Data for IFBI IN saved to IFBI IN.xlsx
# Data for IGM IN saved to IGM IN.xlsx
# Data for IIFL IN saved to IIFL IN.xlsx
# Data for IIFLSEC IN saved to IIFLSEC IN.xlsx
# Data for IECC IN saved to IECC IN.xlsx
# Data for ILFT IN saved to ILFT IN.xlsx
# Data for IMAGICAA IN saved to IMAGICAA IN.xlsx
# No data available for ICCL IN
# Data for IGLY IN saved to IGLY IN.xlsx
# No data available for IHLL IN
# Data for ITDC IN saved to ITDC IN.xlsx
# Data for IHFL IN saved to IHFL IN.xlsx
# Data for IBREL IN saved to IBREL IN.xlsx
# Data for INMART IN saved to INMART IN.xlsx
# Data for INBK IN saved to INBK IN.xlsx
# Data for IEX IN saved to IEX IN.xlsx
# No data available for INLC IN
# Data for IOCL IN saved to IOCL IN.xlsx
# Data for IOB IN saved to IOB IN.xlsx
# Data for IRCTC IN saved to IRCTC IN.xlsx
# Data for IRFC IN saved to IRFC IN.xlsx
# Data for INDIGOPN IN saved to INDIGOPN IN.xlsx
# Data for ICNT IN saved to ICNT IN.xlsx
# Data for INDR IN saved to INDR IN.xlsx
# Data for INDOSTAR IN saved to INDOSTAR IN.xlsx
# Data for IGL IN saved to IGL IN.xlsx
# Data for IPMC IN saved to IPMC IN.xlsx
# Data for INDUSTOW IN saved to INDUSTOW IN.xlsx
# Data for IIB IN saved to IIB IN.xlsx
# Data for IIT IN saved to IIT IN.xlsx
# Data for INFIBEAM IN saved to INFIBEAM IN.xlsx
# Data for ICSL IN saved to ICSL IN.xlsx
# Data for INFOE IN saved to INFOE IN.xlsx
# Data for INFO IN saved to INFO IN.xlsx
# No data available for INRO IN
# No data available for INNOVATO IN
# No data available for BTRF IN
# Data for INXW IN saved to INXW IN.xlsx
# Data for INDA IN saved to INDA IN.xlsx
# Data for INDIGO IN saved to INDIGO IN.xlsx
# No data available for IHFC IN
# No data available for EFS IN
# Data for IPCA IN saved to IPCA IN.xlsx
# Data for IRB IN saved to IRB IN.xlsx
# Data for IRCON IN saved to IRCON IN.xlsx
# Data for ITC IN saved to ITC IN.xlsx
# Data for ITCE IN saved to ITCE IN.xlsx
# Data for ITI IN saved to ITI IN.xlsx
# Data for IVRC IN saved to IVRC IN.xlsx
# No data available for JTPL IN
# Data for JAGP IN saved to JAGP IN.xlsx
# Data for JFI IN saved to JFI IN.xlsx
# Data for JI IN saved to JI IN.xlsx
# Data for JPA IN saved to JPA IN.xlsx
# Data for JPVL IN saved to JPVL IN.xlsx
# No data available for JWTL IN
# Data for JMNA IN saved to JMNA IN.xlsx
# Data for JPIN IN saved to JPIN IN.xlsx
# Data for JBF IN saved to JBF IN.xlsx
# Data for JBMA IN saved to JBMA IN.xlsx
# Data for JETIN IN saved to JETIN IN.xlsx
# Data for JDPF IN saved to JDPF IN.xlsx
# Data for JSAW IN saved to JSAW IN.xlsx
# Data for JDSL IN saved to JDSL IN.xlsx
# Data for JSP IN saved to JSP IN.xlsx
# Data for JINW IN saved to JINW IN.xlsx
# Data for JKLC IN saved to JKLC IN.xlsx
# Data for JKPAPER IN saved to JKPAPER IN.xlsx
# Data for JKI IN saved to JKI IN.xlsx
# Data for JM IN saved to JM IN.xlsx
# Data for JMT IN saved to JMT IN.xlsx
# Data for JCHAC IN saved to JCHAC IN.xlsx
# Data for JSW IN saved to JSW IN.xlsx
# Data for SWH IN saved to SWH IN.xlsx
# Data for JSWISPL IN saved to JSWISPL IN.xlsx
# Data for JSTL IN saved to JSTL IN.xlsx
# Data for JTEKT IN saved to JTEKT IN.xlsx
# Data for JUBI IN saved to JUBI IN.xlsx
# Data for JUBLINGR IN saved to JUBLINGR IN.xlsx
# Data for JUBLPHAR IN saved to JUBLPHAR IN.xlsx
# Data for JUST IN saved to JUST IN.xlsx
# No data available for JINF IN
# Data for JYL IN saved to JYL IN.xlsx
# Data for JYS IN saved to JYS IN.xlsx
# Data for KPR IN saved to KPR IN.xlsx
# Data for KJC IN saved to KJC IN.xlsx
# No data available for KCOM IN
# Data for KPIL IN saved to KPIL IN.xlsx
# Data for KALYANKJ IN saved to KALYANKJ IN.xlsx
# Data for KISP IN saved to KISP IN.xlsx
# Data for KVB IN saved to KVB IN.xlsx
# Data for KARG IN saved to KARG IN.xlsx
# Data for KSCL IN saved to KSCL IN.xlsx
# Data for KCPL IN saved to KCPL IN.xlsx
# Data for KECI IN saved to KECI IN.xlsx
# Data for KEII IN saved to KEII IN.xlsx
# Data for KNM IN saved to KNM IN.xlsx
# Data for KSI IN saved to KSI IN.xlsx
# Data for KEKC IN saved to KEKC IN.xlsx
# Data for KEYFINSE IN saved to KEYFINSE IN.xlsx
# Data for KIOCL IN saved to KIOCL IN.xlsx
# No data available for KMM IN
# Data for KTG IN saved to KTG IN.xlsx
# Data for KNRC IN saved to KNRC IN.xlsx
# Data for KPDL IN saved to KPDL IN.xlsx
# Data for KMB IN saved to KMB IN.xlsx
# Data for KPITTECH IN saved to KPITTECH IN.xlsx
# Data for KRB IN saved to KRB IN.xlsx
# Data for KIMS IN saved to KIMS IN.xlsx
# Data for KSB IN saved to KSB IN.xlsx
# Data for KSK IN saved to KSK IN.xlsx
# Data for KWALITY IN saved to KWALITY IN.xlsx
# Data for LTFH IN saved to LTFH IN.xlsx
# Data for LTTS IN saved to LTTS IN.xlsx
# Data for LOG IN saved to LOG IN.xlsx
# Data for LMW IN saved to LMW IN.xlsx
# Data for LKPS IN saved to LKPS IN.xlsx
# Data for LANCI IN saved to LANCI IN.xlsx
# Data for LT IN saved to LT IN.xlsx
# Data for LATENTVI IN saved to LATENTVI IN.xlsx
# Data for LAURUS IN saved to LAURUS IN.xlsx
# Data for LXCHEM IN saved to LXCHEM IN.xlsx
# Data for LEMONTRE IN saved to LEMONTRE IN.xlsx
# Data for LGBB IN saved to LGBB IN.xlsx
# Data for LICHF IN saved to LICHF IN.xlsx
# Data for LICI IN saved to LICI IN.xlsx
# Data for LIIL IN saved to LIIL IN.xlsx
# Data for LLL IN saved to LLL IN.xlsx
# Data for LTIM IN saved to LTIM IN.xlsx
# Data for LPC IN saved to LPC IN.xlsx
# Data for LUX IN saved to LUX IN.xlsx
# Data for LODHA IN saved to LODHA IN.xlsx
# No data available for MEC IN
# Data for MAHGL IN saved to MAHGL IN.xlsx
# Data for MHSC IN saved to MHSC IN.xlsx
# Data for MHS IN saved to MHS IN.xlsx
# Data for MMFS IN saved to MMFS IN.xlsx
# Data for MM IN saved to MM IN.xlsx
# Data for MHRL IN saved to MHRL IN.xlsx
# Data for MLIFE IN saved to MLIFE IN.xlsx
# Data for MAHLOG IN saved to MAHLOG IN.xlsx
# Data for MAN IN saved to MAN IN.xlsx
# Data for MINF IN saved to MINF IN.xlsx
# Data for MGFL IN saved to MGFL IN.xlsx
# Data for MCF IN saved to MCF IN.xlsx
# Data for MANKIND IN saved to MANKIND IN.xlsx
# Data for MANB IN saved to MANB IN.xlsx
# Data for MRCO IN saved to MRCO IN.xlsx
# Data for MRKS IN saved to MRKS IN.xlsx
# Data for MSIL IN saved to MSIL IN.xlsx
# Data for MASFIN IN saved to MASFIN IN.xlsx
# Data for MAST IN saved to MAST IN.xlsx
# Data for MAXF IN saved to MAXF IN.xlsx
# Data for MAXHEALT IN saved to MAXHEALT IN.xlsx
# Data for MAXINDIA IN saved to MAXINDIA IN.xlsx
# Data for MUNI IN saved to MUNI IN.xlsx
# Data for MBLINFRA IN saved to MBLINFRA IN.xlsx
# Data for MCLR IN saved to MCLR IN.xlsx
# Data for MEDPLUS IN saved to MEDPLUS IN.xlsx
# No data available for MEGHM IN
# Data for MRLN IN saved to MRLN IN.xlsx
# Data for MEFO IN saved to MEFO IN.xlsx
# Data for METROBRA IN saved to METROBRA IN.xlsx
# Data for METROHL IN saved to METROHL IN.xlsx
# Data for MDA IN saved to MDA IN.xlsx
# No data available for MDAFN IN
# Data for HDTI IN saved to HDTI IN.xlsx
# Data for MIDHANI IN saved to MIDHANI IN.xlsx
# Data for MMTC IN saved to MMTC IN.xlsx
# Data for MOIL IN saved to MOIL IN.xlsx
# No data available for MZYM IN
# No data available for MMFI IN
# Data for MOFS IN saved to MOFS IN.xlsx
# Data for MPHL IN saved to MPHL IN.xlsx
# Data for MRF IN saved to MRF IN.xlsx
# Data for MTEL IN saved to MTEL IN.xlsx
# Data for MTARTECH IN saved to MTARTECH IN.xlsx
# Data for MCX IN saved to MCX IN.xlsx
# Data for MJS IN saved to MJS IN.xlsx
# Data for MUTH IN saved to MUTH IN.xlsx
# Data for NARH IN saved to NARH IN.xlsx
# Data for NTCPH IN saved to NTCPH IN.xlsx
# No data available for NATHIND IN
# Data for NACL IN saved to NACL IN.xlsx
# Data for NFL IN saved to NFL IN.xlsx
# Data for NAVA IN saved to NAVA IN.xlsx
# Data for NFIL IN saved to NFIL IN.xlsx
# Data for NACO IN saved to NACO IN.xlsx
# Data for NELI IN saved to NELI IN.xlsx
# Data for NAZARA IN saved to NAZARA IN.xlsx
# Data for NBCC IN saved to NBCC IN.xlsx
# Data for NJCC IN saved to NJCC IN.xlsx
# Data for NDRAUTO IN saved to NDRAUTO IN.xlsx
# Data for NSE IN saved to NSE IN.xlsx
# Data for NEST IN saved to NEST IN.xlsx
# Data for NPST IN saved to NPST IN.xlsx
# No data available for NYCR IN
# Data for NHPC IN saved to NHPC IN.xlsx
# Data for NIIT IN saved to NIIT IN.xlsx
# Data for NILK IN saved to NILK IN.xlsx
# Data for NAM IN saved to NAM IN.xlsx
# Data for NFPI IN saved to NFPI IN.xlsx
# Data for NLC IN saved to NLC IN.xlsx
# Data for NMDC IN saved to NMDC IN.xlsx
# Data for NOCIL IN saved to NOCIL IN.xlsx
# Data for NTB IN saved to NTB IN.xlsx
# Data for NTPC IN saved to NTPC IN.xlsx
# Data for NUVOCO IN saved to NUVOCO IN.xlsx
# Data for OBER IN saved to OBER IN.xlsx
# No data available for OCEANIC IN
# Data for ONGC IN saved to ONGC IN.xlsx
# Data for OINL IN saved to OINL IN.xlsx
# Data for OLECTRA IN saved to OLECTRA IN.xlsx
# Data for OAXE IN saved to OAXE IN.xlsx
# No data available for OMTX IN
# No data available for OPFL IN
# Data for OFSS IN saved to OFSS IN.xlsx
# Data for ORB IN saved to ORB IN.xlsx
# No data available for ORCHASP IN
# Data for ORCMNT IN saved to ORCMNT IN.xlsx
# Data for ORIENTEL IN saved to ORIENTEL IN.xlsx
# Data for OP IN saved to OP IN.xlsx
# No data available for OSI IN
# Data for OWAM IN saved to OWAM IN.xlsx
# Data for PAG IN saved to PAG IN.xlsx
# Data for PARAG IN saved to PARAG IN.xlsx
# No data available for PRCF IN
# Data for PATANJAL IN saved to PATANJAL IN.xlsx
# Data for PEC IN saved to PEC IN.xlsx
# Data for POLICYBZ IN saved to POLICYBZ IN.xlsx
# Data for PCJL IN saved to PCJL IN.xlsx
# Data for PCBL IN saved to PCBL IN.xlsx
# Data for PENL IN saved to PENL IN.xlsx
# Data for PSL IN saved to PSL IN.xlsx
# Data for PSYS IN saved to PSYS IN.xlsx
# Data for PLNG IN saved to PLNG IN.xlsx
# Data for PFIZ IN saved to PFIZ IN.xlsx
# No data available for PHI IN
# Data for PI IN saved to PI IN.xlsx
# Data for PIDI IN saved to PIDI IN.xlsx
# Data for PIEL IN saved to PIEL IN.xlsx
# Data for PIRA IN saved to PIRA IN.xlsx
# Data for PNBHOUSI IN saved to PNBHOUSI IN.xlsx
# Data for PNCL IN saved to PNCL IN.xlsx
# Data for POL IN saved to POL IN.xlsx
# Data for PLM IN saved to PLM IN.xlsx
# Data for POLYCAB IN saved to POLYCAB IN.xlsx
# Data for PPC IN saved to PPC IN.xlsx
# Data for POONAWAL IN saved to POONAWAL IN.xlsx
# Data for POWF IN saved to POWF IN.xlsx
# Data for PWGR IN saved to PWGR IN.xlsx
# Data for PRJ IN saved to PRJ IN.xlsx
# Data for PKI IN saved to PKI IN.xlsx
# Data for PEPL IN saved to PEPL IN.xlsx
# No data available for PRML IN
# Data for PRINCPIP IN saved to PRINCPIP IN.xlsx
# Data for PRSMJ IN saved to PRSMJ IN.xlsx
# Data for PRIVISCL IN saved to PRIVISCL IN.xlsx
# Data for PSLL IN saved to PSLL IN.xlsx
# Data for PSPPL IN saved to PSPPL IN.xlsx
# Data for PTCIF IN saved to PTCIF IN.xlsx
# Data for PTCIN IN saved to PTCIN IN.xlsx
# Data for PUNJ IN saved to PUNJ IN.xlsx
# Data for PNB IN saved to PNB IN.xlsx
# Data for PURVA IN saved to PURVA IN.xlsx
# Data for PVRINOX IN saved to PVRINOX IN.xlsx
# Data for QUESS IN saved to QUESS IN.xlsx
# No data available for RDRG IN
# Data for RVNL IN saved to RVNL IN.xlsx
# Data for RAILTEL IN saved to RAILTEL IN.xlsx
# No data available for GHB IN
# Data for RAJT IN saved to RAJT IN.xlsx
# Data for RJEX IN saved to RJEX IN.xlsx
# Data for RALI IN saved to RALI IN.xlsx
# Data for RAMCO IN saved to RAMCO IN.xlsx
# Data for RMCS IN saved to RMCS IN.xlsx
# Data for RMKF IN saved to RMKF IN.xlsx
# Data for RANA IN saved to RANA IN.xlsx
# Data for RCF IN saved to RCF IN.xlsx
# Data for RPRO IN saved to RPRO IN.xlsx
# Data for RMT IN saved to RMT IN.xlsx
# Data for RATI IN saved to RATI IN.xlsx
# Data for RTPOW IN saved to RTPOW IN.xlsx
# Data for RW IN saved to RW IN.xlsx
# Data for RBK IN saved to RBK IN.xlsx
# Data for RECL IN saved to RECL IN.xlsx
# Data for REDI IN saved to REDI IN.xlsx
# Data for REIA IN saved to REIA IN.xlsx
# Data for RLXF IN saved to RLXF IN.xlsx
# Data for RCOM IN saved to RCOM IN.xlsx
# Data for RELHOME IN saved to RELHOME IN.xlsx
# Data for RIIL IN saved to RIIL IN.xlsx
# Data for RELIANCE IN saved to RELIANCE IN.xlsx
# Data for RELI IN saved to RELI IN.xlsx
# Data for RNAVAL IN saved to RNAVAL IN.xlsx
# Data for RPWR IN saved to RPWR IN.xlsx
# Data for RELG IN saved to RELG IN.xlsx
# Data for REPCO IN saved to REPCO IN.xlsx
# Data for RESP IN saved to RESP IN.xlsx
# Data for RBA IN saved to RBA IN.xlsx
# Data for RHIM IN saved to RHIM IN.xlsx
# Data for RAI IN saved to RAI IN.xlsx
# Data for RITE IN saved to RITE IN.xlsx
# Data for RLTA IN saved to RLTA IN.xlsx
# Data for ROSSARI IN saved to ROSSARI IN.xlsx
# Data for ROUTE IN saved to ROUTE IN.xlsx
# Data for CLFL IN saved to CLFL IN.xlsx
# Data for RUPA IN saved to RUPA IN.xlsx
# Data for SCHAND IN saved to SCHAND IN.xlsx
# No data available for STCL IN
# No data available for SCHM IN
# Data for SADE IN saved to SADE IN.xlsx
# Data for SINP IN saved to SINP IN.xlsx
# Data for MOTHERSO IN saved to MOTHERSO IN.xlsx
# Data for SANL IN saved to SANL IN.xlsx
# Data for SAPPHIRE IN saved to SAPPHIRE IN.xlsx
# No data available for SRPR IN
# Data for SBICARD IN saved to SBICARD IN.xlsx
# Data for SBILIFE IN saved to SBILIFE IN.xlsx
# Data for SCHFL IN saved to SCHFL IN.xlsx
# Data for SCHN IN saved to SCHN IN.xlsx
# Data for SECURKLO IN saved to SECURKLO IN.xlsx
# Data for SEQ IN saved to SEQ IN.xlsx
# Data for SERVOTEC IN saved to SERVOTEC IN.xlsx
# Data for SHANKARA IN saved to SHANKARA IN.xlsx
# Data for SG IN saved to SG IN.xlsx
# Data for SHCR IN saved to SHCR IN.xlsx
# No data available for SFSLTD IN
# Data for SFL IN saved to SFL IN.xlsx
# Data for SLPA IN saved to SLPA IN.xlsx
# Data for SCI IN saved to SCI IN.xlsx
# Data for SHOP IN saved to SHOP IN.xlsx
# Data for SACV IN saved to SACV IN.xlsx
# Data for SRCM IN saved to SRCM IN.xlsx
# Data for SHRS IN saved to SHRS IN.xlsx
# Data for SHRENIK IN saved to SHRENIK IN.xlsx
# No data available for SAMC IN
# Data for SHFL IN saved to SHFL IN.xlsx
# Data for SHRIRAMP IN saved to SHRIRAMP IN.xlsx
# Data for SHYAMMET IN saved to SHYAMMET IN.xlsx
# Data for SIEM IN saved to SIEM IN.xlsx
# Data for SINF IN saved to SINF IN.xlsx
# Data for SINT IN saved to SINT IN.xlsx
# Data for SINTEX IN saved to SINTEX IN.xlsx
# Data for SECIS IN saved to SECIS IN.xlsx
# Data for SSFP IN saved to SSFP IN.xlsx
# Data for SITINET IN saved to SITINET IN.xlsx
# Data for SJVN IN saved to SJVN IN.xlsx
# Data for SKF IN saved to SKF IN.xlsx
# No data available for SKPS IN
# Data for SM IN saved to SM IN.xlsx
# Data for SNLL IN saved to SNLL IN.xlsx
# Data for SOBHA IN saved to SOBHA IN.xlsx
# Data for SOIL IN saved to SOIL IN.xlsx
# Data for SOLARA IN saved to SOLARA IN.xlsx
# Data for SOMC IN saved to SOMC IN.xlsx
# Data for SONACOMS IN saved to SONACOMS IN.xlsx
# Data for SONAHISO IN saved to SONAHISO IN.xlsx
# Data for SSOF IN saved to SSOF IN.xlsx
# No data available for SIPM IN
# Data for SPANDANA IN saved to SPANDANA IN.xlsx
# Data for SJET IN saved to SJET IN.xlsx
# Data for SREI IN saved to SREI IN.xlsx
# Data for SRF IN saved to SRF IN.xlsx
# Data for SRIK IN saved to SRIK IN.xlsx
# Data for STRCEM IN saved to STRCEM IN.xlsx
# No data available for SDTL IN
# Data for STARHEAL IN saved to STARHEAL IN.xlsx
# Data for STARTECK IN saved to STARTECK IN.xlsx
# Data for SWSOLAR IN saved to SWSOLAR IN.xlsx
# Data for SOTL IN saved to SOTL IN.xlsx
# No data available for CHHA IN
# Data for STR IN saved to STR IN.xlsx
# Data for SCHI IN saved to SCHI IN.xlsx
# Data for SUMICHEM IN saved to SUMICHEM IN.xlsx
# Data for SPADV IN saved to SPADV IN.xlsx
# Data for SUNP IN saved to SUNP IN.xlsx
# Data for SUNTV IN saved to SUNTV IN.xlsx
# Data for SBL IN saved to SBL IN.xlsx
# Data for SUF IN saved to SUF IN.xlsx
# Data for SF IN saved to SF IN.xlsx
# Data for SRIN IN saved to SRIN IN.xlsx
# Data for SEL IN saved to SEL IN.xlsx
# Data for SI IN saved to SI IN.xlsx
# Data for SPII IN saved to SPII IN.xlsx
# Data for SPPT IN saved to SPPT IN.xlsx
# Data for SVLS IN saved to SVLS IN.xlsx
# Data for SUVENPHA IN saved to SUVENPHA IN.xlsx
# Data for SUEL IN saved to SUEL IN.xlsx
# Data for SWAN IN saved to SWAN IN.xlsx
# Data for SWE IN saved to SWE IN.xlsx
# Data for SYML IN saved to SYML IN.xlsx
# Data for SHCL IN saved to SHCL IN.xlsx
# Data for SYNG IN saved to SYNG IN.xlsx
# Data for TAKE IN saved to TAKE IN.xlsx
# Data for TNNP IN saved to TNNP IN.xlsx
# Data for TMB IN saved to TMB IN.xlsx
# Data for TANLA IN saved to TANLA IN.xlsx
# Data for TSTY IN saved to TSTY IN.xlsx
# Data for TTCH IN saved to TTCH IN.xlsx
# Data for TCO IN saved to TCO IN.xlsx
# Data for TCOM IN saved to TCOM IN.xlsx
# Data for TCS IN saved to TCS IN.xlsx
# Data for TATACONS IN saved to TATACONS IN.xlsx
# Data for TELX IN saved to TELX IN.xlsx
# Data for TICL IN saved to TICL IN.xlsx
# Data for TML IN saved to TML IN.xlsx
# Data for TTMT IN saved to TTMT IN.xlsx
# Data for TPWR IN saved to TPWR IN.xlsx
# Data for TATASLPL IN saved to TATASLPL IN.xlsx
# Data for TATA IN saved to TATA IN.xlsx
# Data for TTLS IN saved to TTLS IN.xlsx
# Data for TCIEXP IN saved to TCIEXP IN.xlsx
# Data for TCNSBR IN saved to TCNSBR IN.xlsx
# Data for TDPS IN saved to TDPS IN.xlsx
# Data for TEAM IN saved to TEAM IN.xlsx
# Data for TECHM IN saved to TECHM IN.xlsx
# Data for TECHNOE IN saved to TECHNOE IN.xlsx
# Data for TEJASNET IN saved to TEJASNET IN.xlsx
# Data for TXM IN saved to TXM IN.xlsx
# Data for IH IN saved to IH IN.xlsx
# Data for NIACL IN saved to NIACL IN.xlsx
# Data for TRCL IN saved to TRCL IN.xlsx
# Data for TMX IN saved to TMX IN.xlsx
# Data for TC IN saved to TC IN.xlsx
# Data for THYROCAR IN saved to THYROCAR IN.xlsx
# No data available for TAHL IN
# Data for TIME IN saved to TIME IN.xlsx
# Data for TMKN IN saved to TMKN IN.xlsx
# Data for TPC IN saved to TPC IN.xlsx
# Data for TRP IN saved to TRP IN.xlsx
# Data for TPW IN saved to TPW IN.xlsx
# Data for TRPC IN saved to TRPC IN.xlsx
# Data for THEAL IN saved to THEAL IN.xlsx
# Data for TRENT IN saved to TRENT IN.xlsx
# Data for TBZL IN saved to TBZL IN.xlsx
# Data for TRID IN saved to TRID IN.xlsx
# Data for TRE IN saved to TRE IN.xlsx
# Data for TRIV IN saved to TRIV IN.xlsx
# Data for TTKPT IN saved to TTKPT IN.xlsx
# Data for TIINDIA IN saved to TIINDIA IN.xlsx
# Data for TTSL IN saved to TTSL IN.xlsx
# Data for TVTN IN saved to TVTN IN.xlsx
# Data for TV18 IN saved to TV18 IN.xlsx
# Data for TVSL IN saved to TVSL IN.xlsx
# Data for SRTY IN saved to SRTY IN.xlsx
# Data for UCO IN saved to UCO IN.xlsx
# Data for UJJIVAN IN saved to UJJIVAN IN.xlsx
# Data for UJJIVANS IN saved to UJJIVANS IN.xlsx
# Data for UTCEM IN saved to UTCEM IN.xlsx
# Data for UL IN saved to UL IN.xlsx
# Data for UNBK IN saved to UNBK IN.xlsx
# Data for UT IN saved to UT IN.xlsx
# Data for UB IN saved to UB IN.xlsx
# Data for UBBL IN saved to UBBL IN.xlsx
# Data for UNSP IN saved to UNSP IN.xlsx
# Data for UNOMINDA IN saved to UNOMINDA IN.xlsx
# Data for UPLL IN saved to UPLL IN.xlsx
# Data for USM IN saved to USM IN.xlsx
# Data for UTIAM IN saved to UTIAM IN.xlsx
# Data for UTTM IN saved to UTTM IN.xlsx
# No data available for UYFINCOR IN
# Data for VATW IN saved to VATW IN.xlsx
# Data for VGM IN saved to VGM IN.xlsx
# Data for VKI IN saved to VKI IN.xlsx
# Data for VORG IN saved to VORG IN.xlsx
# Data for VTEX IN saved to VTEX IN.xlsx
# Data for VARROC IN saved to VARROC IN.xlsx
# Data for VBL IN saved to VBL IN.xlsx
# Data for MANYAVAR IN saved to MANYAVAR IN.xlsx
# Data for VEDL IN saved to VEDL IN.xlsx
# Data for WH IN saved to WH IN.xlsx
# Data for VI IN saved to VI IN.xlsx
# Data for VGRD IN saved to VGRD IN.xlsx
# Data for VCLF IN saved to VCLF IN.xlsx
# No data available for VJTX IN
# Data for VIJAYA IN saved to VIJAYA IN.xlsx
# Data for VO IN saved to VO IN.xlsx
# Data for VISP IN saved to VISP IN.xlsx
# Data for VMART IN saved to VMART IN.xlsx
# Data for IDEA IN saved to IDEA IN.xlsx
# Data for VOLT IN saved to VOLT IN.xlsx
# Data for VRLL IN saved to VRLL IN.xlsx
# Data for VST IN saved to VST IN.xlsx
# No data available for WAAREE IN
# Data for WLCO IN saved to WLCO IN.xlsx
# Data for WLSI IN saved to WLSI IN.xlsx
# Data for WCPM IN saved to WCPM IN.xlsx
# No data available for WM IN
# Data for WHL IN saved to WHL IN.xlsx
# Data for WHIRL IN saved to WHIRL IN.xlsx
# Data for WPRO IN saved to WPRO IN.xlsx
# Data for WPL IN saved to WPL IN.xlsx
# Data for WONH IN saved to WONH IN.xlsx
# No data available for SPBH IN
# Data for YES IN saved to YES IN.xlsx
# Data for Z IN saved to Z IN.xlsx
# Data for ZLL IN saved to ZLL IN.xlsx
# No data available for ZTL IN
# Data for ZCVCS IN saved to ZCVCS IN.xlsx
# Data for ZDC IN saved to ZDC IN.xlsx
# Data for ZOMATO IN saved to ZOMATO IN.xlsx
# Data for ZYDUSLIF IN saved to ZYDUSLIF IN.xlsx
# Data for ZYWL IN saved to ZYWL IN.xlsx
