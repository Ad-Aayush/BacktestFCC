# %%
import pandas as pd
import openpyxl
from collections import defaultdict
import os

# %%
# !pwd
# Out:
# /home/aayush_ad/BacktestFCC

# %%
stock_data_dict = defaultdict(list)

# %%
def load_excel_sheet(file_path):
    try:
        # Load the Excel file, skipping initial empty rows and setting the header
        data = pd.read_excel(file_path, header=3)
        return data
    except Exception as e:
        print(f"Error loading Excel sheet: {str(e)}")
        return None

# %%
from datetime import datetime

start_date = datetime(2012, 7, 2)

def organize_stock_data(df):
    current_stock = None
    for _, row in df.iterrows():
        if pd.notna(row['CD_Bloomberg Code']):
            current_stock = row['CD_Bloomberg Code']
            if current_stock not in stock_data_dict:
                stock_data_dict[current_stock] = []
        
        if current_stock is not None and pd.notna(row['NDP_Date']) and pd.notna(row['NDP_Close']):
            date = row['NDP_Date']
            close = row['NDP_Close']

            # Convert timestamp to date string
            date_str = date.strftime('%Y-%m-%d')

            # Calculate the number of days since the start date
            days_since_start = (date - start_date).days

            stock_data = {'Date': date_str, 'Days Since Start': days_since_start, 'Close': close}
            stock_data_dict[current_stock].append(stock_data)

# %%
def clean_and_concatenate_data():
    for stock, data in stock_data_dict.items():
        stock_data_dict[stock] = pd.concat(data, ignore_index=True).drop_duplicates().reset_index(drop=True)

# %%
file_names = []

for file in os.listdir('BacktestingData'):
    if 'xlsx' in file:
        file_names.append(file)

print(len(file_names))
file_directory = 'BacktestingData'
# Out:
# 22

# %%
import exchange_calendars as ecals
import pandas as pd

# Get the XBOM trading calendar
xbom_cal = ecals.get_calendar("XBOM")

# Define the date range
start_date = pd.Timestamp("2012-07-02")
end_date = pd.Timestamp("2023-08-10")

# Get the valid trading sessions as strings
trading_sessions_str = xbom_cal.sessions_in_range(start_date, end_date).astype(str)

# Convert back to Timestamp objects with timezone information
trading_sessions = pd.to_datetime(trading_sessions_str)

# Print or use the trading sessions as needed
print(trading_sessions)
# Out:
# DatetimeIndex(['2012-07-02', '2012-07-03', '2012-07-04', '2012-07-05',
#                '2012-07-06', '2012-07-09', '2012-07-10', '2012-07-11',
#                '2012-07-12', '2012-07-13',
#                ...
#                '2023-07-28', '2023-07-31', '2023-08-01', '2023-08-02',
#                '2023-08-03', '2023-08-04', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10'],
#               dtype='datetime64[ns]', length=2736, freq=None)

# %%
if pd.Timestamp("2013-07-04") in trading_sessions:
    print("2013-07-04 is a valid trading session")
else:
    print("2013-07-04 is not a valid trading session")
# Out:
# 2013-07-04 is a valid trading session

# %%
for file_name in file_names:
    file_path = os.path.join(file_directory, file_name)
    data = load_excel_sheet(file_path)
    if data is not None:
        organize_stock_data(data)

# %%
os.makedirs('Data', exist_ok=True)  # Ensure the 'Data' directory exists
os.chdir('Data')
os.makedirs('daily', exist_ok=True)  # Ensure the 'daily' directory exists
os.chdir('daily')

# %%
global_min_date = pd.Timestamp('2012-07-02')
global_max_date = pd.Timestamp('2023-08-10')
given_saturday = pd.Timestamp('2012-07-07')
given_sunday = pd.Timestamp('2012-07-08')

saturday_weekday = given_saturday.weekday()
sunday_weekday = given_sunday.weekday()

# %%
ideal_valid_days = pd.to_datetime(trading_sessions_str)
ideal_valid_days = ideal_valid_days.strftime('%Y-%m-%d')
print(ideal_valid_days)
# ideal_valid_days = trading_sessions
# Out:
# Index(['2012-07-02', '2012-07-03', '2012-07-04', '2012-07-05', '2012-07-06',
#        '2012-07-09', '2012-07-10', '2012-07-11', '2012-07-12', '2012-07-13',
#        ...
#        '2023-07-28', '2023-07-31', '2023-08-01', '2023-08-02', '2023-08-03',
#        '2023-08-04', '2023-08-07', '2023-08-08', '2023-08-09', '2023-08-10'],
#       dtype='object', length=2736)

# %%
ideal_valid_days = pd.to_datetime(trading_sessions_str)
print(ideal_valid_days)
if pd.Timestamp("2013-07-04") in ideal_valid_days:
    print("2013-07-04 is a valid trading session")
else:
    print("2013-07-04 is not a valid trading session")
# Out:
# DatetimeIndex(['2012-07-02', '2012-07-03', '2012-07-04', '2012-07-05',
#                '2012-07-06', '2012-07-09', '2012-07-10', '2012-07-11',
#                '2012-07-12', '2012-07-13',
#                ...
#                '2023-07-28', '2023-07-31', '2023-08-01', '2023-08-02',
#                '2023-08-03', '2023-08-04', '2023-08-07', '2023-08-08',
#                '2023-08-09', '2023-08-10'],
#               dtype='datetime64[ns]', length=2736, freq=None)
# 2013-07-04 is a valid trading session

# %%
for stock, data in stock_data_dict.items():
    formatted_data = pd.DataFrame(data)
    if not formatted_data.empty:
        csv_file_name = f"{stock[:-3]}.csv"
        
        # Sort data by date
        formatted_data = formatted_data.sort_values(by='Date')
        
        # Create additional columns
        formatted_data['open'] = formatted_data['Close']
        formatted_data['high'] = formatted_data['Close']
        formatted_data['low'] = formatted_data['Close']
        formatted_data['volume'] = 1000000    
        formatted_data['dividends'] = 0
        
        # Convert 'Date' to datetime
        formatted_data['Date'] = pd.to_datetime(formatted_data['Date'])
        
        # Set 'Date' as index
        formatted_data.set_index('Date', inplace=True)
        
        # Remove duplicate indices
        formatted_data = formatted_data[~formatted_data.index.duplicated(keep='last')]
        
        # Reindex based on ideal stock's valid trading days and forward fill
        formatted_data = formatted_data.reindex(ideal_valid_days, method='ffill')
        
        # Backward fill for initial values
        formatted_data = formatted_data.bfill()
        
        # Reset index
        formatted_data.reset_index(inplace=True)
        
        # Rename columns
        formatted_data = formatted_data.rename(columns={'index': 'Date', 'Close': 'close', 'dividends': 'dividend'})
        
        # Save to CSV
        formatted_data.to_csv(csv_file_name, index=False)
        print(f"Data for {stock} saved to {csv_file_name}")
    else:
        print(f"No data available for {stock}")
# Out:
# Data for 3M IN saved to 3M.csv
# Data for ARTO IN saved to ARTO.csv
# Data for ABAN IN saved to ABAN.csv
# Data for ABB IN saved to ABB.csv
# Data for ACC IN saved to ACC.csv
# Data for ADE IN saved to ADE.csv
# Data for ADSEZ IN saved to ADSEZ.csv
# Data for ADANI IN saved to ADANI.csv
# Data for ABML IN saved to ABML.csv
# Data for RMDA IN saved to RMDA.csv
# Data for ATFL IN saved to ATFL.csv
# Data for AIAE IN saved to AIAE.csv
# Data for AKZO IN saved to AKZO.csv
# Data for AACL IN saved to AACL.csv
# Data for AGLL IN saved to AGLL.csv
# Data for ALOK IN saved to ALOK.csv
# Data for AMRJ IN saved to AMRJ.csv
# Data for ACEM IN saved to ACEM.csv
# Data for ARCP IN saved to ARCP.csv
# Data for APIL IN saved to APIL.csv
# Data for APHS IN saved to APHS.csv
# Data for APTY IN saved to APTY.csv
# Data for APTR IN saved to APTR.csv
# Data for ARVND IN saved to ARVND.csv
# Data for AISG IN saved to AISG.csv
# Data for AL IN saved to AL.csv
# Data for ASBL IN saved to ASBL.csv
# Data for APNT IN saved to APNT.csv
# Data for ASTRA IN saved to ASTRA.csv
# Data for ATLP IN saved to ATLP.csv
# Data for ARBP IN saved to ARBP.csv
# Data for ATXL IN saved to ATXL.csv
# Data for AVNT IN saved to AVNT.csv
# Data for AXSB IN saved to AXSB.csv
# Data for BJAUT IN saved to BJAUT.csv
# Data for BAJAJCON IN saved to BAJAJCON.csv
# Data for BAF IN saved to BAF.csv
# Data for BJFIN IN saved to BJFIN.csv
# Data for BAJAJHEA IN saved to BAJAJHEA.csv
# Data for BJH IN saved to BJH.csv
# Data for BJHI IN saved to BJHI.csv
# Data for BIL IN saved to BIL.csv
# Data for BILT IN saved to BILT.csv
# Data for BRCM IN saved to BRCM.csv
# Data for BANDHAN IN saved to BANDHAN.csv
# Data for BOB IN saved to BOB.csv
# Data for BOI IN saved to BOI.csv
# Data for BOMH IN saved to BOMH.csv
# Data for BASF IN saved to BASF.csv
# Data for BATA IN saved to BATA.csv
# Data for BYRCS IN saved to BYRCS.csv
# Data for BEML IN saved to BEML.csv
# Data for BRGR IN saved to BRGR.csv
# Data for BFUT IN saved to BFUT.csv
# Data for BDL IN saved to BDL.csv
# Data for BHE IN saved to BHE.csv
# Data for BHFC IN saved to BHFC.csv
# Data for BHEL IN saved to BHEL.csv
# Data for BPCL IN saved to BPCL.csv
# Data for BRSN IN saved to BRSN.csv
# Data for BHARTI IN saved to BHARTI.csv
# Data for BIOS IN saved to BIOS.csv
# Data for BCORP IN saved to BCORP.csv
# Data for BSOFT IN saved to BSOFT.csv
# Data for BLIS IN saved to BLIS.csv
# Data for BLSIN IN saved to BLSIN.csv
# Data for BDE IN saved to BDE.csv
# Data for BLSTR IN saved to BLSTR.csv
# Data for BBTC IN saved to BBTC.csv
# Data for BRFL IN saved to BRFL.csv
# Data for BORORENE IN saved to BORORENE.csv
# Data for BOS IN saved to BOS.csv
# Data for BRGD IN saved to BRGD.csv
# Data for BCG IN saved to BCG.csv
# Data for BRIT IN saved to BRIT.csv
# Data for BSE IN saved to BSE.csv
# Data for CCON IN saved to CCON.csv
# Data for CADSYS IN saved to CADSYS.csv
# Data for CFIN IN saved to CFIN.csv
# Data for CAMPUS IN saved to CAMPUS.csv
# Data for CANF IN saved to CANF.csv
# Data for CBK IN saved to CBK.csv
# Data for CLPL IN saved to CLPL.csv
# Data for CGCL IN saved to CGCL.csv
# Data for CU IN saved to CU.csv
# Data for CARE IN saved to CARE.csv
# Data for CSTRL IN saved to CSTRL.csv
# Data for CEAT IN saved to CEAT.csv
# Data for CBOI IN saved to CBOI.csv
# Data for CDSL IN saved to CDSL.csv
# Data for CENK IN saved to CENK.csv
# Data for CPBI IN saved to CPBI.csv
# Data for CENT IN saved to CENT.csv
# Data for CESC IN saved to CESC.csv
# Data for CGPOWER IN saved to CGPOWER.csv
# Data for CHALET IN saved to CHALET.csv
# Data for CHMB IN saved to CHMB.csv
# Data for CHEMPLAS IN saved to CHEMPLAS.csv
# Data for MRL IN saved to MRL.csv
# Data for CHOLAHLD IN saved to CHOLAHLD.csv
# Data for CIFC IN saved to CIFC.csv
# Data for CIEINDIA IN saved to CIEINDIA.csv
# Data for CIPLA IN saved to CIPLA.csv
# Data for CUBK IN saved to CUBK.csv
# Data for CLEDU IN saved to CLEDU.csv
# Data for CLEAN IN saved to CLEAN.csv
# Data for COAL IN saved to COAL.csv
# Data for COCHIN IN saved to COCHIN.csv
# Data for CCD IN saved to CCD.csv
# Data for COFORGE IN saved to COFORGE.csv
# Data for CAMS IN saved to CAMS.csv
# Data for CCRI IN saved to CCRI.csv
# Data for CRIN IN saved to CRIN.csv
# Data for COXK IN saved to COXK.csv
# Data for CRAFTSMA IN saved to CRAFTSMA.csv
# Data for CREDAG IN saved to CREDAG.csv
# Data for CRISIL IN saved to CRISIL.csv
# Data for CROMPTON IN saved to CROMPTON.csv
# Data for CSBBANK IN saved to CSBBANK.csv
# Data for KKC IN saved to KKC.csv
# Data for CYL IN saved to CYL.csv
# Data for DBCL IN saved to DBCL.csv
# Data for DABUR IN saved to DABUR.csv
# Data for DALBHARA IN saved to DALBHARA.csv
# Data for DATAPATT IN saved to DATAPATT.csv
# Data for DCI IN saved to DCI.csv
# Data for DCBB IN saved to DCBB.csv
# Data for DCMNVL IN saved to DCMNVL.csv
# Data for DCMS IN saved to DCMS.csv
# Data for DCW IN saved to DCW.csv
# Data for DN IN saved to DN.csv
# Data for DELHIVER IN saved to DELHIVER.csv
# Data for DELTA IN saved to DELTA.csv
# Data for DEN IN saved to DEN.csv
# Data for DEVYANI IN saved to DEVYANI.csv
# Data for DHANI IN saved to DHANI.csv
# Data for DHLBK IN saved to DHLBK.csv
# Data for DAGRI IN saved to DAGRI.csv
# Data for DBL IN saved to DBL.csv
# Data for DITV IN saved to DITV.csv
# Data for DCAL IN saved to DCAL.csv
# Data for DIVI IN saved to DIVI.csv
# Data for DIXON IN saved to DIXON.csv
# Data for DLFU IN saved to DLFU.csv
# Data for DRRD IN saved to DRRD.csv
# Data for DCIL IN saved to DCIL.csv
# Data for DYTC IN saved to DYTC.csv
# Data for EID IN saved to EID.csv
# Data for EASEMYTR IN saved to EASEMYTR.csv
# Data for ECLX IN saved to ECLX.csv
# Data for EDEL IN saved to EDEL.csv
# Data for EDSL IN saved to EDSL.csv
# Data for EIM IN saved to EIM.csv
# Data for EIH IN saved to EIH.csv
# Data for ELSC IN saved to ELSC.csv
# Data for ELEQ IN saved to ELEQ.csv
# Data for HMN IN saved to HMN.csv
# Data for ENDU IN saved to ENDU.csv
# Data for ENGR IN saved to ENGR.csv
# Data for ENIL IN saved to ENIL.csv
# Data for EPLL IN saved to EPLL.csv
# Data for EQUIPPP IN saved to EQUIPPP.csv
# Data for EQUITASB IN saved to EQUITASB.csv
# Data for ERIS IN saved to ERIS.csv
# Data for EROS IN saved to EROS.csv
# Data for ESAB IN saved to ESAB.csv
# Data for ESCORTS IN saved to ESCORTS.csv
# Data for ESL IN saved to ESL.csv
# Data for EVRIN IN saved to EVRIN.csv
# Data for EXID IN saved to EXID.csv
# Data for FDCLT IN saved to FDCLT.csv
# Data for FMGI IN saved to FMGI.csv
# Data for FINEORG IN saved to FINEORG.csv
# Data for FNXC IN saved to FNXC.csv
# Data for FNXP IN saved to FNXP.csv
# Data for FSOL IN saved to FSOL.csv
# Data for FORH IN saved to FORH.csv
# Data for NYKAA IN saved to NYKAA.csv
# Data for FCON IN saved to FCON.csv
# Data for FLFL IN saved to FLFL.csv
# Data for FRETAIL IN saved to FRETAIL.csv
# Data for GABR IN saved to GABR.csv
# Data for GAIL IN saved to GAIL.csv
# Data for GALSURF IN saved to GALSURF.csv
# Data for GRSE IN saved to GRSE.csv
# Data for GTFL IN saved to GTFL.csv
# Data for GTIC IN saved to GTIC.csv
# Data for GAYP IN saved to GAYP.csv
# Data for GEPIL IN saved to GEPIL.csv
# Data for GETD IN saved to GETD.csv
# Data for GICRE IN saved to GICRE.csv
# Data for GHCL IN saved to GHCL.csv
# Data for GILL IN saved to GILL.csv
# Data for GLAND IN saved to GLAND.csv
# Data for GLXO IN saved to GLXO.csv
# Data for GLS IN saved to GLS.csv
# Data for GNP IN saved to GNP.csv
# Data for GMM IN saved to GMM.csv
# Data for GMRI IN saved to GMRI.csv
# Data for GOCOLORS IN saved to GOCOLORS.csv
# Data for GP IN saved to GP.csv
# Data for GOAGRO IN saved to GOAGRO.csv
# Data for GCPL IN saved to GCPL.csv
# Data for GDSP IN saved to GDSP.csv
# Data for GPL IN saved to GPL.csv
# Data for GRAN IN saved to GRAN.csv
# Data for GRIL IN saved to GRIL.csv
# Data for GRASIM IN saved to GRASIM.csv
# Data for GRV IN saved to GRV.csv
# Data for GREENP IN saved to GREENP.csv
# Data for MTLM IN saved to MTLM.csv
# Data for GWN IN saved to GWN.csv
# Data for GRP IN saved to GRP.csv
# Data for GTLI IN saved to GTLI.csv
# Data for CF IN saved to CF.csv
# Data for GAEX IN saved to GAEX.csv
# Data for FLUOROCH IN saved to FLUOROCH.csv
# Data for GUJGA IN saved to GUJGA.csv
# Data for GMDC IN saved to GMDC.csv
# Data for GNFC IN saved to GNFC.csv
# Data for GPPV IN saved to GPPV.csv
# Data for GSFC IN saved to GSFC.csv
# Data for GUJS IN saved to GUJS.csv
# Data for GOLI IN saved to GOLI.csv
# Data for HAPPSTMN IN saved to HAPPSTMN.csv
# Data for HATH IN saved to HATH.csv
# Data for HTSMF IN saved to HTSMF.csv
# Data for HAVL IN saved to HAVL.csv
# Data for HCLI IN saved to HCLI.csv
# Data for HCLT IN saved to HCLT.csv
# Data for HDFCAMC IN saved to HDFCAMC.csv
# Data for HDFCB IN saved to HDFCB.csv
# Data for HDFCLIFE IN saved to HDFCLIFE.csv
# Data for HEIM IN saved to HEIM.csv
# Data for HEMIPROP IN saved to HEMIPROP.csv
# Data for HTFL IN saved to HTFL.csv
# Data for HMCL IN saved to HMCL.csv
# Data for HMFC IN saved to HMFC.csv
# Data for HKCI IN saved to HKCI.csv
# Data for HSCH IN saved to HSCH.csv
# Data for HSS IN saved to HSS.csv
# Data for HNDL IN saved to HNDL.csv
# Data for HGSL IN saved to HGSL.csv
# Data for HNAL IN saved to HNAL.csv
# Data for HDCM IN saved to HDCM.csv
# Data for HCP IN saved to HCP.csv
# Data for HM IN saved to HM.csv
# Data for HPCL IN saved to HPCL.csv
# Data for HUVR IN saved to HUVR.csv
# Data for HZ IN saved to HZ.csv
# Data for POWERIND IN saved to POWERIND.csv
# Data for HLEGLAS IN saved to HLEGLAS.csv
# Data for HMT IN saved to HMT.csv
# Data for HOMEFIRS IN saved to HOMEFIRS.csv
# Data for HWA IN saved to HWA.csv
# Data for HUDCO IN saved to HUDCO.csv
# Data for HDIL IN saved to HDIL.csv
# Data for HTML IN saved to HTML.csv
# Data for HUB IN saved to HUB.csv
# Data for HUIN IN saved to HUIN.csv
# Data for ICICIBC IN saved to ICICIBC.csv
# Data for ICICIGI IN saved to ICICIGI.csv
# Data for IPRU IN saved to IPRU.csv
# Data for ISEC IN saved to ISEC.csv
# Data for ICRA IN saved to ICRA.csv
# Data for IDBI IN saved to IDBI.csv
# Data for IDFCFB IN saved to IDFCFB.csv
# Data for IDFC IN saved to IDFC.csv
# Data for IFBI IN saved to IFBI.csv
# Data for IFCI IN saved to IFCI.csv
# Data for IGM IN saved to IGM.csv
# Data for IIFL IN saved to IIFL.csv
# Data for IIFLSEC IN saved to IIFLSEC.csv
# Data for IECC IN saved to IECC.csv
# Data for ILFT IN saved to ILFT.csv
# Data for IGLY IN saved to IGLY.csv
# Data for ITDC IN saved to ITDC.csv
# Data for IHFL IN saved to IHFL.csv
# Data for IBREL IN saved to IBREL.csv
# Data for INMART IN saved to INMART.csv
# Data for INBK IN saved to INBK.csv
# Data for IEX IN saved to IEX.csv
# Data for IOCL IN saved to IOCL.csv
# Data for IOB IN saved to IOB.csv
# Data for IRCTC IN saved to IRCTC.csv
# Data for IRFC IN saved to IRFC.csv
# Data for INDIGOPN IN saved to INDIGOPN.csv
# Data for ICNT IN saved to ICNT.csv
# Data for INDR IN saved to INDR.csv
# Data for INDOSTAR IN saved to INDOSTAR.csv
# Data for IGL IN saved to IGL.csv
# Data for IPMC IN saved to IPMC.csv
# Data for INDUSTOW IN saved to INDUSTOW.csv
# Data for IIB IN saved to IIB.csv
# Data for IIT IN saved to IIT.csv
# Data for INFIBEAM IN saved to INFIBEAM.csv
# Data for INFOE IN saved to INFOE.csv
# Data for INFO IN saved to INFO.csv
# Data for INXW IN saved to INXW.csv
# Data for INDA IN saved to INDA.csv
# Data for INDIGO IN saved to INDIGO.csv
# Data for IPCA IN saved to IPCA.csv
# Data for IRB IN saved to IRB.csv
# Data for IRCON IN saved to IRCON.csv
# Data for ITC IN saved to ITC.csv
# Data for ITCE IN saved to ITCE.csv
# Data for ITI IN saved to ITI.csv
# Data for JAGP IN saved to JAGP.csv
# Data for JFI IN saved to JFI.csv
# Data for JI IN saved to JI.csv
# Data for JPA IN saved to JPA.csv
# Data for JPVL IN saved to JPVL.csv
# Data for JMNA IN saved to JMNA.csv
# Data for JPIN IN saved to JPIN.csv
# Data for JBF IN saved to JBF.csv
# Data for JBMA IN saved to JBMA.csv
# Data for JETIN IN saved to JETIN.csv
# Data for JDPF IN saved to JDPF.csv
# Data for JSAW IN saved to JSAW.csv
# Data for JDSL IN saved to JDSL.csv
# Data for JSP IN saved to JSP.csv
# Data for JINW IN saved to JINW.csv
# Data for JKLC IN saved to JKLC.csv
# Data for JKPAPER IN saved to JKPAPER.csv
# Data for JKI IN saved to JKI.csv
# Data for JM IN saved to JM.csv
# Data for JMT IN saved to JMT.csv
# Data for JCHAC IN saved to JCHAC.csv
# Data for JSW IN saved to JSW.csv
# Data for SWH IN saved to SWH.csv
# Data for JSTL IN saved to JSTL.csv
# Data for JTEKT IN saved to JTEKT.csv
# Data for JUBI IN saved to JUBI.csv
# Data for JUBLINGR IN saved to JUBLINGR.csv
# Data for JUBLPHAR IN saved to JUBLPHAR.csv
# Data for JUST IN saved to JUST.csv
# Data for JYL IN saved to JYL.csv
# Data for JYS IN saved to JYS.csv
# Data for KPR IN saved to KPR.csv
# Data for KJC IN saved to KJC.csv
# Data for KPIL IN saved to KPIL.csv
# Data for KALYANKJ IN saved to KALYANKJ.csv
# Data for KNPL IN saved to KNPL.csv
# Data for KVB IN saved to KVB.csv
# Data for KSCL IN saved to KSCL.csv
# Data for KCPL IN saved to KCPL.csv
# Data for KECI IN saved to KECI.csv
# Data for KEII IN saved to KEII.csv
# Data for KNM IN saved to KNM.csv
# Data for KSI IN saved to KSI.csv
# Data for KEKC IN saved to KEKC.csv
# Data for KEYFINSE IN saved to KEYFINSE.csv
# Data for KIOCL IN saved to KIOCL.csv
# Data for KTG IN saved to KTG.csv
# Data for KNRC IN saved to KNRC.csv
# Data for KPDL IN saved to KPDL.csv
# Data for KMB IN saved to KMB.csv
# Data for KPITTECH IN saved to KPITTECH.csv
# Data for KRB IN saved to KRB.csv
# Data for KIMS IN saved to KIMS.csv
# Data for KSB IN saved to KSB.csv
# Data for LTFH IN saved to LTFH.csv
# Data for LTTS IN saved to LTTS.csv
# Data for LOG IN saved to LOG.csv
# Data for LMW IN saved to LMW.csv
# Data for LKPS IN saved to LKPS.csv
# Data for LT IN saved to LT.csv
# Data for LATENTVI IN saved to LATENTVI.csv
# Data for LAURUS IN saved to LAURUS.csv
# Data for LXCHEM IN saved to LXCHEM.csv
# Data for LEMONTRE IN saved to LEMONTRE.csv
# Data for LGBB IN saved to LGBB.csv
# Data for LICHF IN saved to LICHF.csv
# Data for LICI IN saved to LICI.csv
# Data for LIIL IN saved to LIIL.csv
# Data for LLL IN saved to LLL.csv
# Data for LTIM IN saved to LTIM.csv
# Data for LPC IN saved to LPC.csv
# Data for LUX IN saved to LUX.csv
# Data for LODHA IN saved to LODHA.csv
# Data for MAHGL IN saved to MAHGL.csv
# Data for MTNL IN saved to MTNL.csv
# Data for MHSC IN saved to MHSC.csv
# Data for MHS IN saved to MHS.csv
# Data for MMFS IN saved to MMFS.csv
# Data for MM IN saved to MM.csv
# Data for MHRL IN saved to MHRL.csv
# Data for MLIFE IN saved to MLIFE.csv
# Data for MAHLOG IN saved to MAHLOG.csv
# Data for MAN IN saved to MAN.csv
# Data for MINF IN saved to MINF.csv
# Data for MGFL IN saved to MGFL.csv
# Data for MCF IN saved to MCF.csv
# Data for MRCO IN saved to MRCO.csv
# Data for MRKS IN saved to MRKS.csv
# Data for MSIL IN saved to MSIL.csv
# Data for MASFIN IN saved to MASFIN.csv
# Data for MAST IN saved to MAST.csv
# Data for MAXF IN saved to MAXF.csv
# Data for MAXHEALT IN saved to MAXHEALT.csv
# Data for MAXINDIA IN saved to MAXINDIA.csv
# Data for MUNI IN saved to MUNI.csv
# Data for MBLINFRA IN saved to MBLINFRA.csv
# Data for MCLR IN saved to MCLR.csv
# Data for MEDPLUS IN saved to MEDPLUS.csv
# Data for MRLN IN saved to MRLN.csv
# Data for MEFO IN saved to MEFO.csv
# Data for METROBRA IN saved to METROBRA.csv
# Data for METROHL IN saved to METROHL.csv
# Data for MDA IN saved to MDA.csv
# Data for HDTI IN saved to HDTI.csv
# Data for MIDHANI IN saved to MIDHANI.csv
# Data for MMTC IN saved to MMTC.csv
# Data for MOIL IN saved to MOIL.csv
# Data for MOFS IN saved to MOFS.csv
# Data for MPHL IN saved to MPHL.csv
# Data for MRF IN saved to MRF.csv
# Data for MTEL IN saved to MTEL.csv
# Data for MTARTECH IN saved to MTARTECH.csv
# Data for MCX IN saved to MCX.csv
# Data for MJS IN saved to MJS.csv
# Data for MUTH IN saved to MUTH.csv
# Data for NARH IN saved to NARH.csv
# Data for NTCPH IN saved to NTCPH.csv
# Data for NACL IN saved to NACL.csv
# Data for NFL IN saved to NFL.csv
# Data for NFIL IN saved to NFIL.csv
# Data for NACO IN saved to NACO.csv
# Data for NELI IN saved to NELI.csv
# Data for NAZARA IN saved to NAZARA.csv
# Data for NBCC IN saved to NBCC.csv
# Data for NJCC IN saved to NJCC.csv
# Data for NDRAUTO IN saved to NDRAUTO.csv
# Data for NSE IN saved to NSE.csv
# Data for NEST IN saved to NEST.csv
# Data for NPST IN saved to NPST.csv
# Data for NHPC IN saved to NHPC.csv
# Data for NIIT IN saved to NIIT.csv
# Data for NILK IN saved to NILK.csv
# Data for NAM IN saved to NAM.csv
# Data for NFPI IN saved to NFPI.csv
# Data for NLC IN saved to NLC.csv
# Data for NMDC IN saved to NMDC.csv
# Data for NOCIL IN saved to NOCIL.csv
# Data for NTB IN saved to NTB.csv
# Data for NTPC IN saved to NTPC.csv
# Data for NUVOCO IN saved to NUVOCO.csv
# Data for OBER IN saved to OBER.csv
# Data for ONGC IN saved to ONGC.csv
# Data for OINL IN saved to OINL.csv
# Data for OLECTRA IN saved to OLECTRA.csv
# Data for OAXE IN saved to OAXE.csv
# Data for OFSS IN saved to OFSS.csv
# Data for ORCMNT IN saved to ORCMNT.csv
# Data for ORIENTEL IN saved to ORIENTEL.csv
# Data for OP IN saved to OP.csv
# Data for OAL IN saved to OAL.csv
# Data for OWAM IN saved to OWAM.csv
# Data for PAG IN saved to PAG.csv
# Data for PARAG IN saved to PARAG.csv
# Data for PATANJAL IN saved to PATANJAL.csv
# Data for PEC IN saved to PEC.csv
# Data for POLICYBZ IN saved to POLICYBZ.csv
# Data for PCJL IN saved to PCJL.csv
# Data for PCBL IN saved to PCBL.csv
# Data for PENL IN saved to PENL.csv
# Data for PSL IN saved to PSL.csv
# Data for PSYS IN saved to PSYS.csv
# Data for PLNG IN saved to PLNG.csv
# Data for PFIZ IN saved to PFIZ.csv
# Data for PI IN saved to PI.csv
# Data for PIDI IN saved to PIDI.csv
# Data for PIEL IN saved to PIEL.csv
# Data for PNBHOUSI IN saved to PNBHOUSI.csv
# Data for PNCL IN saved to PNCL.csv
# Data for PLM IN saved to PLM.csv
# Data for POLYCAB IN saved to POLYCAB.csv
# Data for PPC IN saved to PPC.csv
# Data for POONAWAL IN saved to POONAWAL.csv
# Data for POWF IN saved to POWF.csv
# Data for PWGR IN saved to PWGR.csv
# Data for PRJ IN saved to PRJ.csv
# Data for PKI IN saved to PKI.csv
# Data for PEPL IN saved to PEPL.csv
# Data for PRINCPIP IN saved to PRINCPIP.csv
# Data for PRSMJ IN saved to PRSMJ.csv
# Data for PRIVISCL IN saved to PRIVISCL.csv
# Data for PGHL IN saved to PGHL.csv
# Data for PSPPL IN saved to PSPPL.csv
# Data for PTCIN IN saved to PTCIN.csv
# Data for PUNJ IN saved to PUNJ.csv
# Data for PNB IN saved to PNB.csv
# Data for PURVA IN saved to PURVA.csv
# Data for PVRINOX IN saved to PVRINOX.csv
# Data for QUESS IN saved to QUESS.csv
# Data for RVNL IN saved to RVNL.csv
# Data for RAILTEL IN saved to RAILTEL.csv
# Data for RAJT IN saved to RAJT.csv
# Data for RJEX IN saved to RJEX.csv
# Data for RALI IN saved to RALI.csv
# Data for RAMCO IN saved to RAMCO.csv
# Data for RMCS IN saved to RMCS.csv
# Data for RMKF IN saved to RMKF.csv
# Data for RANA IN saved to RANA.csv
# Data for RMT IN saved to RMT.csv
# Data for RATI IN saved to RATI.csv
# Data for RTPOW IN saved to RTPOW.csv
# Data for RW IN saved to RW.csv
# Data for RBK IN saved to RBK.csv
# Data for RECL IN saved to RECL.csv
# Data for REDI IN saved to REDI.csv
# Data for RLXF IN saved to RLXF.csv
# Data for RCAPT IN saved to RCAPT.csv
# Data for RCOM IN saved to RCOM.csv
# Data for RELHOME IN saved to RELHOME.csv
# Data for RIIL IN saved to RIIL.csv
# Data for RELIANCE IN saved to RELIANCE.csv
# Data for RELI IN saved to RELI.csv
# Data for RNAVAL IN saved to RNAVAL.csv
# Data for RPWR IN saved to RPWR.csv
# Data for RELG IN saved to RELG.csv
# Data for REPCO IN saved to REPCO.csv
# Data for RESP IN saved to RESP.csv
# Data for RBA IN saved to RBA.csv
# Data for RHIM IN saved to RHIM.csv
# Data for RAI IN saved to RAI.csv
# Data for RITE IN saved to RITE.csv
# Data for RLTA IN saved to RLTA.csv
# Data for ROSSARI IN saved to ROSSARI.csv
# Data for ROUTE IN saved to ROUTE.csv
# Data for CLFL IN saved to CLFL.csv
# Data for RUPA IN saved to RUPA.csv
# Data for SCHAND IN saved to SCHAND.csv
# Data for SADE IN saved to SADE.csv
# Data for SINP IN saved to SINP.csv
# Data for MOTHERSO IN saved to MOTHERSO.csv
# Data for SANL IN saved to SANL.csv
# Data for SAPPHIRE IN saved to SAPPHIRE.csv
# Data for SBICARD IN saved to SBICARD.csv
# Data for SBILIFE IN saved to SBILIFE.csv
# Data for SCHFL IN saved to SCHFL.csv
# Data for SCHN IN saved to SCHN.csv
# Data for SEQ IN saved to SEQ.csv
# Data for SERVOTEC IN saved to SERVOTEC.csv
# Data for SHANKARA IN saved to SHANKARA.csv
# Data for SG IN saved to SG.csv
# Data for SHCR IN saved to SHCR.csv
# Data for SFL IN saved to SFL.csv
# Data for SLPA IN saved to SLPA.csv
# Data for SCI IN saved to SCI.csv
# Data for SHOP IN saved to SHOP.csv
# Data for SRCM IN saved to SRCM.csv
# Data for SHRS IN saved to SHRS.csv
# Data for SHRENIK IN saved to SHRENIK.csv
# Data for SHFL IN saved to SHFL.csv
# Data for SHRIRAMP IN saved to SHRIRAMP.csv
# Data for SHYAMMET IN saved to SHYAMMET.csv
# Data for SIEM IN saved to SIEM.csv
# Data for SINF IN saved to SINF.csv
# Data for SINT IN saved to SINT.csv
# Data for SINTEX IN saved to SINTEX.csv
# Data for SECIS IN saved to SECIS.csv
# Data for SITINET IN saved to SITINET.csv
# Data for SJVN IN saved to SJVN.csv
# Data for SKF IN saved to SKF.csv
# Data for SM IN saved to SM.csv
# Data for SNLL IN saved to SNLL.csv
# Data for SOBHA IN saved to SOBHA.csv
# Data for SOIL IN saved to SOIL.csv
# Data for SOLARA IN saved to SOLARA.csv
# Data for SOMC IN saved to SOMC.csv
# Data for SONACOMS IN saved to SONACOMS.csv
# Data for SONAHISO IN saved to SONAHISO.csv
# Data for SSOF IN saved to SSOF.csv
# Data for SPANDANA IN saved to SPANDANA.csv
# Data for SJET IN saved to SJET.csv
# Data for SREI IN saved to SREI.csv
# Data for SRF IN saved to SRF.csv
# Data for SRIK IN saved to SRIK.csv
# Data for STRCEM IN saved to STRCEM.csv
# Data for STARHEAL IN saved to STARHEAL.csv
# Data for STARTECK IN saved to STARTECK.csv
# Data for SBIN IN saved to SBIN.csv
# Data for SAIL IN saved to SAIL.csv
# Data for SWSOLAR IN saved to SWSOLAR.csv
# Data for SOTL IN saved to SOTL.csv
# Data for STR IN saved to STR.csv
# Data for SCHI IN saved to SCHI.csv
# Data for SUMICHEM IN saved to SUMICHEM.csv
# Data for SPADV IN saved to SPADV.csv
# Data for SUNP IN saved to SUNP.csv
# Data for SUNTV IN saved to SUNTV.csv
# Data for SBL IN saved to SBL.csv
# Data for SUF IN saved to SUF.csv
# Data for SF IN saved to SF.csv
# Data for SRIN IN saved to SRIN.csv
# Data for SEL IN saved to SEL.csv
# Data for SI IN saved to SI.csv
# Data for SPII IN saved to SPII.csv
# Data for SPPT IN saved to SPPT.csv
# Data for SVLS IN saved to SVLS.csv
# Data for SUVENPHA IN saved to SUVENPHA.csv
# Data for SUEL IN saved to SUEL.csv
# Data for SWAN IN saved to SWAN.csv
# Data for SWE IN saved to SWE.csv
# Data for SYML IN saved to SYML.csv
# Data for SYNG IN saved to SYNG.csv
# Data for TAKE IN saved to TAKE.csv
# Data for TNNP IN saved to TNNP.csv
# Data for TANLA IN saved to TANLA.csv
# Data for TSTY IN saved to TSTY.csv
# Data for TTCH IN saved to TTCH.csv
# Data for TCO IN saved to TCO.csv
# Data for TCOM IN saved to TCOM.csv
# Data for TCS IN saved to TCS.csv
# Data for TATACONS IN saved to TATACONS.csv
# Data for TELX IN saved to TELX.csv
# Data for TICL IN saved to TICL.csv
# Data for TML IN saved to TML.csv
# Data for TTMT IN saved to TTMT.csv
# Data for TPWR IN saved to TPWR.csv
# Data for TATASLPL IN saved to TATASLPL.csv
# Data for TATA IN saved to TATA.csv
# Data for TTLS IN saved to TTLS.csv
# Data for TCIEXP IN saved to TCIEXP.csv
# Data for TCNSBR IN saved to TCNSBR.csv
# Data for TDPS IN saved to TDPS.csv
# Data for TEAM IN saved to TEAM.csv
# Data for TECHM IN saved to TECHM.csv
# Data for TECHNOE IN saved to TECHNOE.csv
# Data for TEJASNET IN saved to TEJASNET.csv
# Data for TXM IN saved to TXM.csv
# Data for NIACL IN saved to NIACL.csv
# Data for TRCL IN saved to TRCL.csv
# Data for TMX IN saved to TMX.csv
# Data for TC IN saved to TC.csv
# Data for THYROCAR IN saved to THYROCAR.csv
# Data for TIME IN saved to TIME.csv
# Data for TMKN IN saved to TMKN.csv
# Data for TPC IN saved to TPC.csv
# Data for TTAN IN saved to TTAN.csv
# Data for TRP IN saved to TRP.csv
# Data for TPW IN saved to TPW.csv
# Data for TRPC IN saved to TRPC.csv
# Data for THEAL IN saved to THEAL.csv
# Data for TRENT IN saved to TRENT.csv
# Data for TBZL IN saved to TBZL.csv
# Data for TRID IN saved to TRID.csv
# Data for TRE IN saved to TRE.csv
# Data for TRIV IN saved to TRIV.csv
# Data for TTKPT IN saved to TTKPT.csv
# Data for TIINDIA IN saved to TIINDIA.csv
# Data for TVTN IN saved to TVTN.csv
# Data for TV18 IN saved to TV18.csv
# Data for TVSL IN saved to TVSL.csv
# Data for SRTY IN saved to SRTY.csv
# Data for UCO IN saved to UCO.csv
# Data for UFLX IN saved to UFLX.csv
# Data for UJJIVAN IN saved to UJJIVAN.csv
# Data for UJJIVANS IN saved to UJJIVANS.csv
# Data for UTCEM IN saved to UTCEM.csv
# Data for UL IN saved to UL.csv
# Data for UNBK IN saved to UNBK.csv
# Data for UT IN saved to UT.csv
# Data for UBBL IN saved to UBBL.csv
# Data for UNSP IN saved to UNSP.csv
# Data for UNOMINDA IN saved to UNOMINDA.csv
# Data for UPLL IN saved to UPLL.csv
# Data for USM IN saved to USM.csv
# Data for UTIAM IN saved to UTIAM.csv
# Data for UTTM IN saved to UTTM.csv
# Data for VATW IN saved to VATW.csv
# Data for VGM IN saved to VGM.csv
# Data for VKI IN saved to VKI.csv
# Data for VORG IN saved to VORG.csv
# Data for VTEX IN saved to VTEX.csv
# Data for VARROC IN saved to VARROC.csv
# Data for VBL IN saved to VBL.csv
# Data for MANYAVAR IN saved to MANYAVAR.csv
# Data for VEDL IN saved to VEDL.csv
# Data for WH IN saved to WH.csv
# Data for VI IN saved to VI.csv
# Data for VGRD IN saved to VGRD.csv
# Data for VIJAYA IN saved to VIJAYA.csv
# Data for VO IN saved to VO.csv
# Data for VISP IN saved to VISP.csv
# Data for VMART IN saved to VMART.csv
# Data for IDEA IN saved to IDEA.csv
# Data for VOLT IN saved to VOLT.csv
# Data for VRLL IN saved to VRLL.csv
# Data for VST IN saved to VST.csv
# Data for WLCO IN saved to WLCO.csv
# Data for WLSI IN saved to WLSI.csv
# Data for WCPM IN saved to WCPM.csv
# Data for WHL IN saved to WHL.csv
# Data for WHIRL IN saved to WHIRL.csv
# Data for WPRO IN saved to WPRO.csv
# Data for WPL IN saved to WPL.csv
# Data for WONH IN saved to WONH.csv
# Data for YES IN saved to YES.csv
# Data for Z IN saved to Z.csv
# Data for ZLL IN saved to ZLL.csv
# Data for ZCVCS IN saved to ZCVCS.csv
# Data for ZOMATO IN saved to ZOMATO.csv
# Data for ZYDUSLIF IN saved to ZYDUSLIF.csv
# Data for ZYWL IN saved to ZYWL.csv
# Data for 360ONE IN saved to 360ONE.csv
# Data for 63MOONS IN saved to 63MOONS.csv
# Data for ARTD IN saved to ARTD.csv
# Data for AAVAS IN saved to AAVAS.csv
# Data for BOOT IN saved to BOOT.csv
# Data for ABGS IN saved to ABGS.csv
# Data for ADANIT IN saved to ADANIT.csv
# Data for ADANIGR IN saved to ADANIGR.csv
# Data for ATGL IN saved to ATGL.csv
# Data for AWLTD IN saved to AWLTD.csv
# Data for ABCAP IN saved to ABCAP.csv
# Data for ABFRL IN saved to ABFRL.csv
# Data for ABSLAMC IN saved to ABSLAMC.csv
# Data for ADVENZY IN saved to ADVENZY.csv
# Data for AGIS IN saved to AGIS.csv
# Data for AETHER IN saved to AETHER.csv
# Data for AFFLE IN saved to AFFLE.csv
# Data for AHLU IN saved to AHLU.csv
# Data for AJP IN saved to AJP.csv
# Data for ALBC IN saved to ALBC.csv
# Data for ALPM IN saved to ALPM.csv
# Data for ALKEM IN saved to ALKEM.csv
# Data for ALBK IN saved to ALBK.csv
# No data available for AMHL IN
# Data for AMBER IN saved to AMBER.csv
# Data for AMTK IN saved to AMTK.csv
# Data for ANGELONE IN saved to ANGELONE.csv
# Data for ANURAS IN saved to ANURAS.csv
# Data for APR IN saved to APR.csv
# Data for APAT IN saved to APAT.csv
# Data for APTUS IN saved to APTUS.csv
# Data for ACI IN saved to ACI.csv
# Data for ARVINDFA IN saved to ARVINDFA.csv
# Data for ASFI IN saved to ASFI.csv
# Data for ASTERDM IN saved to ASTERDM.csv
# Data for AUBANK IN saved to AUBANK.csv
# Data for DMART IN saved to DMART.csv
# Data for BLA IN saved to BLA.csv
# No data available for BFTL IN
# Data for BHAFIN IN saved to BHAFIN.csv
# No data available for BHUDEVI IN
# Data for BIKAJI IN saved to BIKAJI.csv
# No data available for BCMA IN
# Data for CAFL IN saved to CAFL.csv
# Data for CAST IN saved to CAST.csv
# No data available for CRCL IN
# Data for CLTO IN saved to CLTO.csv
# Data for CLGT IN saved to CLGT.csv
# Data for CETL IN saved to CETL.csv
# No data available for CMBL IN
# Data for DFPC IN saved to DFPC.csv
# Data for DDLL IN saved to DDLL.csv
# No data available for DKOF IN
# Data for ELDP IN saved to ELDP.csv
# Data for ERIE IN saved to ERIE.csv
# Data for EDA IN saved to EDA.csv
# No data available for EXLI IN
# No data available for FCTS IN
# No data available for FCCI IN
# Data for FIVESTAR IN saved to FIVESTAR.csv
# No data available for FLXF IN
# No data available for FPL IN
# No data available for FSL IN
# Data for GMON IN saved to GMON.csv
# Data for GBGLOBAL IN saved to GBGLOBAL.csv
# No data available for GENP IN
# No data available for GSI IN
# Data for GITG IN saved to GITG.csv
# Data for MEDANTA IN saved to MEDANTA.csv
# Data for GWOS IN saved to GWOS.csv
# Data for GOFF IN saved to GOFF.csv
# No data available for GRSM IN
# No data available for GJF IN
# No data available for GUJSPIN IN
# Data for GNC IN saved to GNC.csv
# Data for GVKP IN saved to GVKP.csv
# Data for HEG IN saved to HEG.csv
# No data available for HMF IN
# No data available for HHC IN
# Data for HLV IN saved to HLV.csv
# No data available for HSPL IN
# No data available for NYC IN
# Data for IMAGICAA IN saved to IMAGICAA.csv
# No data available for ICCL IN
# No data available for IHLL IN
# No data available for INLC IN
# Data for ICSL IN saved to ICSL.csv
# No data available for INRO IN
# No data available for INNOVATO IN
# No data available for BTRF IN
# No data available for IHFC IN
# No data available for EFS IN
# Data for IVRC IN saved to IVRC.csv
# No data available for JTPL IN
# No data available for JWTL IN
# Data for JSWISPL IN saved to JSWISPL.csv
# No data available for JINF IN
# No data available for KCOM IN
# Data for KISP IN saved to KISP.csv
# Data for KARG IN saved to KARG.csv
# No data available for KMM IN
# Data for KSK IN saved to KSK.csv
# Data for KWALITY IN saved to KWALITY.csv
# Data for LANCI IN saved to LANCI.csv
# No data available for MEC IN
# Data for MANKIND IN saved to MANKIND.csv
# Data for MANB IN saved to MANB.csv
# No data available for MEGHM IN
# No data available for MDAFN IN
# No data available for MZYM IN
# No data available for MMFI IN
# No data available for NATHIND IN
# Data for NAVA IN saved to NAVA.csv
# No data available for NYCR IN
# No data available for OCEANIC IN
# No data available for OMTX IN
# No data available for OPFL IN
# Data for ORB IN saved to ORB.csv
# No data available for ORCHASP IN
# No data available for OSI IN
# No data available for PRCF IN
# No data available for PHI IN
# Data for PIRA IN saved to PIRA.csv
# Data for POL IN saved to POL.csv
# No data available for PRML IN
# Data for PSLL IN saved to PSLL.csv
# Data for PTCIF IN saved to PTCIF.csv
# No data available for RDRG IN
# No data available for GHB IN
# Data for RCF IN saved to RCF.csv
# Data for RPRO IN saved to RPRO.csv
# Data for REIA IN saved to REIA.csv
# No data available for STCL IN
# No data available for SCHM IN
# No data available for SRPR IN
# Data for SECURKLO IN saved to SECURKLO.csv
# No data available for SFSLTD IN
# Data for SACV IN saved to SACV.csv
# No data available for SAMC IN
# Data for SSFP IN saved to SSFP.csv
# No data available for SKPS IN
# No data available for SIPM IN
# No data available for SDTL IN
# No data available for CHHA IN
# Data for SHCL IN saved to SHCL.csv
# Data for TMB IN saved to TMB.csv
# Data for IH IN saved to IH.csv
# No data available for TAHL IN
# Data for TTSL IN saved to TTSL.csv
# Data for UB IN saved to UB.csv
# No data available for UYFINCOR IN
# Data for VCLF IN saved to VCLF.csv
# No data available for VJTX IN
# No data available for WAAREE IN
# No data available for WM IN
# No data available for SPBH IN
# No data available for ZTL IN
# Data for ZDC IN saved to ZDC.csv

# %%
formatted_data
# Out:
#            Date  Days Since Start   close    open    high     low   volume  \
# 0    2012-07-02                 0  185.95  185.95  185.95  185.95  1000000
# 1    2012-07-03                 1  189.05  189.05  189.05  189.05  1000000
# 2    2012-07-04                 2  189.65  189.65  189.65  189.65  1000000
# 3    2012-07-05                 3  197.35  197.35  197.35  197.35  1000000
# 4    2012-07-06                 4  195.80  195.80  195.80  195.80  1000000
# ...         ...               ...     ...     ...     ...     ...      ...
# 2731 2023-08-04              4050  117.70  117.70  117.70  117.70  1000000
# 2732 2023-08-07              4053  121.25  121.25  121.25  121.25  1000000
# 2733 2023-08-08              4054  118.70  118.70  118.70  118.70  1000000
# 2734 2023-08-09              4055  117.65  117.65  117.65  117.65  1000000
# 2735 2023-08-10              4056  117.15  117.15  117.15  117.15  1000000
#
#       dividend
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 2731         0
# 2732         0
# 2733         0
# 2734         0
# 2735         0
#
# [2736 rows x 8 columns]
